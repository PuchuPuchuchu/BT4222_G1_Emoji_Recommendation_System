# %%
import pandas as pd
import numpy as np
import emoji
import nltk

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /Users/apple/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/apple/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/apple/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## emoji related functions

# %%
def emojiname2icon(name):
    return emoji.emojize(f":{name.replace(' ','_')}:")

emojiname2icon('smiling face with hearts')
# Out:
# '🥰'

# %% [markdown]
# ## Combine data from different data sources

# %%
#Produce Emoji_DF[emoji_id, emoji_name]
top_20_emoji_name = [
    'face with tears of joy', # funny happy
    
    'red heart', #love
    
    'broken heart', #no love
    
    'thumbs up', #encouragement
    
    'smiling face with smiling eyes', #happy
    
    'loudly crying face', #pure sad
    
    'clapping hands', #congradualation
    
    'fire', #hot /sexy
    
    'face screaming in fear', #shock
    
    'pile of poo', #non-sense, disapproval
    
    'face with symbols on mouth', #anger
    
    'eggplant', #horny
    
    'face savoring food', # craving
    
    'hundred points', #approval
    
    'folded hands', #pray
    
    
]

emoji_reference = {'emoji_name':top_20_emoji_name,'emoji_id':[i for i in range(len(top_20_emoji_name))]}
emoji_df =  pd.DataFrame(emoji_reference)
emoji_df
# Out:
#                         emoji_name  emoji_id
# 0           face with tears of joy         0
# 1                        red heart         1
# 2                     broken heart         2
# 3                        thumbs up         3
# 4   smiling face with smiling eyes         4
# 5               loudly crying face         5
# 6                   clapping hands         6
# 7                             fire         7
# 8           face screaming in fear         8
# 9                      pile of poo         9
# 10      face with symbols on mouth        10
# 11                        eggplant        11
# 12              face savoring food        12
# 13                  hundred points        13
# 14                    folded hands        14

# %% [markdown]
# # Read in Data

# %%
train_df = pd.read_csv('train 15 emoji.csv')
test_df = pd.read_csv('test 15 emoji.csv')

# %% [markdown]
# # Data

# %%
train_df
# Out:
#         emoji_id                                            content  \
# 0              7                   announcement on Sunday 6pm ! 🔥\n
# 1              6  Chelsea legend Frank Lampard will receive the ...
# 2              8                     HE JUST DESTROYED THIS MAN 😱\n
# 3             10                          It’s twitter I’m sure 🤬\n
# 4              5          Yeah and I think u need a phone no too😭\n
# ...          ...                                                ...
# 156724         6  Dirty Heads - Celebrate feat. The Unlikely Can...
# 156725         4  ETHAN AND GRAYSON WERE NOMINATED FOR A SHORTY ...
# 156726         1  [EXO-CBX ALBUM GIVEAWAY] Hi! will be hosting h...
# 156727        13               TEN who? He’s “HUNDRED” now!! 😂💯🙌🏼\n
# 156728        12  High school senior vs. College senior Same per...
#
#                                           cleaned_content  cleaned_content_len
# 0                                  announcement sunday pm                    3
# 1       chelsea legend frank lampard receive football ...                   12
# 2                                             destroy man                    2
# 3                                         twitter im sure                    3
# 4                                 yeah think u need phone                    5
# ...                                                   ...                  ...
# 156724  dirty head celebrate feat unlikely candidate o...                   12
# 156725  ethan grayson nominate shorty award make sure ...                   13
# 156726  exocbx album giveaway hi host first please giv...                   11
# 156727                                     ten he hundred                    3
# 156728  high school senior v college person less angry...                    9
#
# [156729 rows x 4 columns]

# %%
test_df
# Out:
#        emoji_id                                            content  \
# 0             4  might be reuniting with la famiglia next month...
# 1            12                        getting that booty ate 🍑😋\n
# 2             1              Which baddies wnat to be posted?😋❤️\n
# 3             3  Yeah our King is avid reader and so wise and H...
# 4             7      The HOTTEST Air Jordans Of All Time😍🔥🔥🔥💦💦👌🏻\n
# ...         ...                                                ...
# 67126         1                    Veggie Facts! We RULE! ❤️❤️❤️\n
# 67127         2  BLESSING 💋💘❤️💓💔💕💖💗💙💚💛💜🖤💝💞💟❣️💟💞💝🖤💜💛💚💙💗💖💕💔💓❤️💘💋💘...
# 67128         5                            Ugh this hurts me 😭😭😭\n
# 67129         0            Perfect example of, "Tit for tat":  😂\n
# 67130         9  🚨🚨Judiciary Cmte Subpoenas 🐀FBI for all 👉💩Clin...
#
#                                          cleaned_content  cleaned_content_len
# 0         might reunite la famiglia next month che bello                    8
# 1                                          get booty ate                    3
# 2                                       baddie wnat post                    3
# 3      yeah king avid reader wise son mohammed learns...                    9
# 4                                    hot air jordan time                    4
# ...                                                  ...                  ...
# 67126                                   veggie fact rule                    3
# 67127                                           blessing                    1
# 67128                                           ugh hurt                    2
# 67129                            perfect example tit tat                    4
# 67130  judiciary cmte subpoena fbi clinton investigat...                   14
#
# [67131 rows x 4 columns]

# %%
emoji_df
# Out:
#                         emoji_name  emoji_id
# 0           face with tears of joy         0
# 1                        red heart         1
# 2                     broken heart         2
# 3                        thumbs up         3
# 4   smiling face with smiling eyes         4
# 5               loudly crying face         5
# 6                   clapping hands         6
# 7                             fire         7
# 8           face screaming in fear         8
# 9                      pile of poo         9
# 10      face with symbols on mouth        10
# 11                        eggplant        11
# 12              face savoring food        12
# 13                  hundred points        13
# 14                    folded hands        14

# %% [markdown]
# #  LSTM + CNN

# %%
from keras.preprocessing.text import Tokenizer
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Embedding
from keras.models import Sequential
from keras.layers import Dropout, Dense, LSTM, Bidirectional,Embedding, GlobalMaxPool1D
import numpy as np
from keras.utils import pad_sequences
from gensim.models import KeyedVectors
import math
import random
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# CNN
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Flatten
from keras.layers import Input
from keras.layers import concatenate
from keras.models import Model
# Out:
# 2023-04-13 18:12:28.499849: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Read in data and shuffle emoji library
random.seed(4222)
emoji_shuffled = shuffle(emoji_df)
print(emoji_shuffled)
# Out:
#                         emoji_name  emoji_id
# 6                   clapping hands         6
# 2                     broken heart         2
# 9                      pile of poo         9
# 10      face with symbols on mouth        10
# 7                             fire         7
# 0           face with tears of joy         0
# 1                        red heart         1
# 4   smiling face with smiling eyes         4
# 3                        thumbs up         3
# 5               loudly crying face         5
# 12              face savoring food        12
# 13                  hundred points        13
# 8           face screaming in fear         8
# 14                    folded hands        14
# 11                        eggplant        11

# %%
# Record the separting index of train vs test split
split_index = len(train_df)

# %%
all_df = pd.concat([train_df, test_df])
tweets_content = all_df["cleaned_content"]
tokenizer = Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', split=" ", lower=True)
tokenizer.fit_on_texts(tweets_content)
all_df["encoded_content"] = tokenizer.texts_to_sequences(tweets_content)
print(all_df["encoded_content"][:10])
# Out:
# 0                                     [2188, 427, 288]
# 1    [1324, 490, 3288, 11236, 648, 715, 384, 3522, ...
# 2                                            [788, 44]
# 3                                        [146, 3, 167]
# 4                                [308, 42, 8, 25, 350]
# 5          [1409, 146, 295, 383, 321, 12471, 26, 2346]
# 6      [3, 29218, 14, 61, 1844, 214, 11237, 700, 7822]
# 7                                             [4, 545]
# 8    [230, 85, 2, 732, 11238, 9492, 6176, 28, 29, 8...
# 9                                            [4, 2272]
# Name: encoded_content, dtype: object

# %%
train_df = all_df.iloc[:split_index]
test_df = all_df.iloc[split_index:]

# %%
train_df
# Out:
#         emoji_id                                            content  \
# 0              7                   announcement on Sunday 6pm ! 🔥\n
# 1              6  Chelsea legend Frank Lampard will receive the ...
# 2              8                     HE JUST DESTROYED THIS MAN 😱\n
# 3             10                          It’s twitter I’m sure 🤬\n
# 4              5          Yeah and I think u need a phone no too😭\n
# ...          ...                                                ...
# 156724         6  Dirty Heads - Celebrate feat. The Unlikely Can...
# 156725         4  ETHAN AND GRAYSON WERE NOMINATED FOR A SHORTY ...
# 156726         1  [EXO-CBX ALBUM GIVEAWAY] Hi! will be hosting h...
# 156727        13               TEN who? He’s “HUNDRED” now!! 😂💯🙌🏼\n
# 156728        12  High school senior vs. College senior Same per...
#
#                                           cleaned_content  \
# 0                                  announcement sunday pm
# 1       chelsea legend frank lampard receive football ...
# 2                                             destroy man
# 3                                         twitter im sure
# 4                                 yeah think u need phone
# ...                                                   ...
# 156724  dirty head celebrate feat unlikely candidate o...
# 156725  ethan grayson nominate shorty award make sure ...
# 156726  exocbx album giveaway hi host first please giv...
# 156727                                     ten he hundred
# 156728  high school senior v college person less angry...
#
#         cleaned_content_len                                    encoded_content
# 0                         3                                   [2188, 427, 288]
# 1                        12  [1324, 490, 3288, 11236, 648, 715, 384, 3522, ...
# 2                         2                                          [788, 44]
# 3                         3                                      [146, 3, 167]
# 4                         5                              [308, 42, 8, 25, 350]
# ...                     ...                                                ...
# 156724                   12  [756, 265, 658, 1765, 14102, 3215, 374, 40, 86...
# 156725                   13  [5666, 5235, 1768, 1299, 384, 11, 167, 6, 309,...
# 156726                   11  [1937, 235, 275, 338, 2054, 75, 28, 52, 4, 151...
# 156727                    3                                  [1548, 159, 2660]
# 156728                    9      [252, 202, 1125, 313, 780, 234, 523, 833, 20]
#
# [156729 rows x 5 columns]

# %%
test_df
# Out:
#        emoji_id                                            content  \
# 0             4  might be reuniting with la famiglia next month...
# 1            12                        getting that booty ate 🍑😋\n
# 2             1              Which baddies wnat to be posted?😋❤️\n
# 3             3  Yeah our King is avid reader and so wise and H...
# 4             7      The HOTTEST Air Jordans Of All Time😍🔥🔥🔥💦💦👌🏻\n
# ...         ...                                                ...
# 67126         1                    Veggie Facts! We RULE! ❤️❤️❤️\n
# 67127         2  BLESSING 💋💘❤️💓💔💕💖💗💙💚💛💜🖤💝💞💟❣️💟💞💝🖤💜💛💚💙💗💖💕💔💓❤️💘💋💘...
# 67128         5                            Ugh this hurts me 😭😭😭\n
# 67129         0            Perfect example of, "Tit for tat":  😂\n
# 67130         9  🚨🚨Judiciary Cmte Subpoenas 🐀FBI for all 👉💩Clin...
#
#                                          cleaned_content  cleaned_content_len  \
# 0         might reunite la famiglia next month che bello                    8
# 1                                          get booty ate                    3
# 2                                       baddie wnat post                    3
# 3      yeah king avid reader wise son mohammed learns...                    9
# 4                                    hot air jordan time                    4
# ...                                                  ...                  ...
# 67126                                   veggie fact rule                    3
# 67127                                           blessing                    1
# 67128                                           ugh hurt                    2
# 67129                            perfect example tit tat                    4
# 67130  judiciary cmte subpoena fbi clinton investigat...                   14
#
#                                          encoded_content
# 0         [438, 4182, 631, 59426, 122, 228, 5115, 23000]
# 1                                          [1, 875, 911]
# 2                                      [2760, 5036, 177]
# 3      [308, 387, 26206, 6382, 3214, 463, 9164, 18666...
# 4                                   [173, 783, 2042, 18]
# ...                                                  ...
# 67126                                  [3536, 388, 1010]
# 67127                                              [611]
# 67128                                        [1360, 299]
# 67129                            [340, 1974, 1659, 2757]
# 67130  [7826, 7827, 7367, 710, 894, 2725, 8293, 30, 7...
#
# [67131 rows x 5 columns]

# %%
# Define max_length
import seaborn as sns
lengths = [len(seq) for seq in train_df["encoded_content"]]
max_length = max(lengths)
print("max_length =", max_length)
sns.countplot(x = lengths)
# Out:
# max_length = 34
# <Axes: ylabel='count'>

# %%
# Apply padding to data set and convert labels to bit vector form
train_X = pad_sequences(train_df["encoded_content"], padding='post', maxlen = max_length)
train_Y = train_df["emoji_id"]
train_X
# Out:
# array([[2188,  427,  288, ...,    0,    0,    0],
#        [1324,  490, 3288, ...,    0,    0,    0],
#        [ 788,   44,    0, ...,    0,    0,    0],
#        ...,
#        [1937,  235,  275, ...,    0,    0,    0],
#        [1548,  159, 2660, ...,    0,    0,    0],
#        [ 252,  202, 1125, ...,    0,    0,    0]], dtype=int32)

# %%
total_emoji_number = len(emoji_df)

# %%
# Padding for test data
# Apply padding to data set and convert labels to bit vector form
test_X = pad_sequences(test_df["encoded_content"], padding='post', maxlen = max_length)
test_Y = test_df["emoji_id"]

# %%
print(train_X.shape)
print(len(train_Y))
print(test_X.shape)
print(len(test_Y))
# Out:
# (156729, 34)
# 156729
# (67131, 34)
# 67131

# %%
# View the vocab library
vocab = tokenizer.word_index
vocab
# Out:
# {'get': 1,
#  'like': 2,
#  'im': 3,
#  'love': 4,
#  'amp': 5,
#  'go': 6,
#  'good': 7,
#  'u': 8,
#  'day': 9,
#  'dont': 10,
#  'make': 11,
#  'follow': 12,
#  'one': 13,
#  'see': 14,
#  'thank': 15,
#  'retweet': 16,
#  'back': 17,
#  'time': 18,
#  'new': 19,
#  'happy': 20,
#  'want': 21,
#  'know': 22,
#  'rt': 23,
#  'look': 24,
#  'need': 25,
#  'say': 26,
#  'come': 27,
#  'please': 28,
#  'let': 29,
#  'cant': 30,
#  'today': 31,
#  'take': 32,
#  'best': 33,
#  'much': 34,
#  'well': 35,
#  'fuck': 36,
#  'year': 37,
#  'shit': 38,
#  'everyone': 39,
#  'video': 40,
#  'people': 41,
#  'think': 42,
#  'really': 43,
#  'man': 44,
#  'god': 45,
#  'watch': 46,
#  'great': 47,
#  'na': 48,
#  'tweet': 49,
#  'never': 50,
#  'guy': 51,
#  'give': 52,
#  'still': 53,
#  'life': 54,
#  'keep': 55,
#  'yall': 56,
#  'girl': 57,
#  'right': 58,
#  'big': 59,
#  'work': 60,
#  'always': 61,
#  'miss': 62,
#  'thanks': 63,
#  'thing': 64,
#  'thats': 65,
#  'feel': 66,
#  'even': 67,
#  'youre': 68,
#  'friend': 69,
#  'help': 70,
#  'last': 71,
#  'ever': 72,
#  'wait': 73,
#  'luck': 74,
#  'first': 75,
#  'http': 76,
#  'heart': 77,
#  'way': 78,
#  'free': 79,
#  'show': 80,
#  'second': 81,
#  'baby': 82,
#  'birthday': 83,
#  'real': 84,
#  'would': 85,
#  'hope': 86,
#  'omg': 87,
#  'start': 88,
#  'live': 89,
#  'boy': 90,
#  'oh': 91,
#  'vote': 92,
#  'gain': 93,
#  'play': 94,
#  'fan': 95,
#  'every': 96,
#  'try': 97,
#  'tell': 98,
#  'song': 99,
#  'morning': 100,
#  'week': 101,
#  'use': 102,
#  'find': 103,
#  'nigga': 104,
#  'as': 105,
#  'win': 106,
#  'k': 107,
#  'night': 108,
#  'break': 109,
#  'stop': 110,
#  'do': 111,
#  'call': 112,
#  'beautiful': 113,
#  'bad': 114,
#  'everything': 115,
#  'another': 116,
#  'someone': 117,
#  'game': 118,
#  'dick': 119,
#  'hard': 120,
#  'ill': 121,
#  'next': 122,
#  'army': 123,
#  'hour': 124,
#  'full': 125,
#  'leave': 126,
#  'talk': 127,
#  'aint': 128,
#  'follower': 129,
#  'bitch': 130,
#  'wan': 131,
#  'bless': 132,
#  'gon': 133,
#  'end': 134,
#  'world': 135,
#  'tonight': 136,
#  'music': 137,
#  'wow': 138,
#  'ive': 139,
#  'yes': 140,
#  'little': 141,
#  'cry': 142,
#  'th': 143,
#  'put': 144,
#  'wish': 145,
#  'twitter': 146,
#  'could': 147,
#  'ready': 148,
#  'check': 149,
#  'old': 150,
#  'support': 151,
#  'drop': 152,
#  'lose': 153,
#  'family': 154,
#  'trump': 155,
#  'nice': 156,
#  'retweets': 157,
#  'lol': 158,
#  'he': 159,
#  'damn': 160,
#  'proud': 161,
#  'hate': 162,
#  'home': 163,
#  'kid': 164,
#  'sex': 165,
#  'turn': 166,
#  'sure': 167,
#  'cute': 168,
#  'didnt': 169,
#  'yo': 170,
#  'soon': 171,
#  'congratulation': 172,
#  'hot': 173,
#  'woman': 174,
#  'away': 175,
#  'team': 176,
#  'post': 177,
#  'bro': 178,
#  'many': 179,
#  'hit': 180,
#  'sound': 181,
#  'stay': 182,
#  'happen': 183,
#  'send': 184,
#  'enjoy': 185,
#  'mean': 186,
#  'kill': 187,
#  'lot': 188,
#  'ask': 189,
#  'black': 190,
#  'part': 191,
#  'already': 192,
#  'something': 193,
#  'lil': 194,
#  'hear': 195,
#  'goal': 196,
#  'via': 197,
#  'tomorrow': 198,
#  'amaze': 199,
#  'x': 200,
#  'top': 201,
#  'school': 202,
#  'believe': 203,
#  'bts': 204,
#  'fast': 205,
#  'eat': 206,
#  'money': 207,
#  'two': 208,
#  'listen': 209,
#  'face': 210,
#  'w': 211,
#  'nothing': 212,
#  'long': 213,
#  'ya': 214,
#  'congrats': 215,
#  'word': 216,
#  'ta': 217,
#  'may': 218,
#  'reply': 219,
#  'shes': 220,
#  'fire': 221,
#  'finally': 222,
#  'job': 223,
#  'run': 224,
#  'smile': 225,
#  'name': 226,
#  'dm': 227,
#  'month': 228,
#  'whole': 229,
#  'hey': 230,
#  'share': 231,
#  'remember': 232,
#  'true': 233,
#  'person': 234,
#  'album': 235,
#  'also': 236,
#  'die': 237,
#  'since': 238,
#  'care': 239,
#  'season': 240,
#  'b': 241,
#  'rts': 242,
#  'fun': 243,
#  'save': 244,
#  'around': 245,
#  'cause': 246,
#  'doesnt': 247,
#  'n': 248,
#  'change': 249,
#  'forget': 250,
#  'sorry': 251,
#  'high': 252,
#  'join': 253,
#  'h': 254,
#  'update': 255,
#  'pic': 256,
#  'must': 257,
#  'brother': 258,
#  'wont': 259,
#  'ur': 260,
#  'hell': 261,
#  'together': 262,
#  'bring': 263,
#  'minute': 264,
#  'head': 265,
#  'pay': 266,
#  'meet': 267,
#  'welcome': 268,
#  'deserve': 269,
#  'rip': 270,
#  'lie': 271,
#  'crazy': 272,
#  'exo': 273,
#  'super': 274,
#  'giveaway': 275,
#  'without': 276,
#  'sweet': 277,
#  'mom': 278,
#  'pray': 279,
#  'suck': 280,
#  'story': 281,
#  'comment': 282,
#  'read': 283,
#  'sleep': 284,
#  'literally': 285,
#  'winner': 286,
#  'buy': 287,
#  'pm': 288,
#  'weekend': 289,
#  'dog': 290,
#  'piece': 291,
#  'young': 292,
#  'funny': 293,
#  'trend': 294,
#  'account': 295,
#  'pretty': 296,
#  'news': 297,
#  'walk': 298,
#  'hurt': 299,
#  'valentine': 300,
#  'dear': 301,
#  'open': 302,
#  'child': 303,
#  'peace': 304,
#  'move': 305,
#  'favorite': 306,
#  'picture': 307,
#  'yeah': 308,
#  'link': 309,
#  'moment': 310,
#  'million': 311,
#  'anything': 312,
#  'v': 313,
#  'enough': 314,
#  'awesome': 315,
#  'cock': 316,
#  'hand': 317,
#  'tf': 318,
#  'tag': 319,
#  'dream': 320,
#  'forever': 321,
#  'rest': 322,
#  'anyone': 323,
#  'point': 324,
#  'car': 325,
#  'appreciate': 326,
#  'pick': 327,
#  'actually': 328,
#  'food': 329,
#  'st': 330,
#  'theyre': 331,
#  'sister': 332,
#  'prayer': 333,
#  'pain': 334,
#  'ok': 335,
#  'challenge': 336,
#  'photo': 337,
#  'hi': 338,
#  'mad': 339,
#  'perfect': 340,
#  'sad': 341,
#  'view': 342,
#  'tho': 343,
#  'dance': 344,
#  'wrong': 345,
#  'lady': 346,
#  'wake': 347,
#  'ig': 348,
#  'whats': 349,
#  'phone': 350,
#  'hair': 351,
#  'pussy': 352,
#  'amazing': 353,
#  'cut': 354,
#  'white': 355,
#  'sexy': 356,
#  'beat': 357,
#  'fight': 358,
#  'place': 359,
#  'af': 360,
#  'single': 361,
#  'house': 362,
#  'release': 363,
#  'r': 364,
#  'okay': 365,
#  'dead': 366,
#  'movie': 367,
#  'else': 368,
#  'eye': 369,
#  'date': 370,
#  'star': 371,
#  'nobody': 372,
#  'yet': 373,
#  'official': 374,
#  'lmao': 375,
#  'though': 376,
#  'id': 377,
#  'friday': 378,
#  'special': 379,
#  'mind': 380,
#  'hold': 381,
#  'absolutely': 382,
#  'close': 383,
#  'award': 384,
#  'laugh': 385,
#  'catch': 386,
#  'king': 387,
#  'fact': 388,
#  'excite': 389,
#  'plan': 390,
#  'sign': 391,
#  'add': 392,
#  'grow': 393,
#  'mood': 394,
#  'daddy': 395,
#  'country': 396,
#  'president': 397,
#  'roll': 398,
#  'saw': 399,
#  'pls': 400,
#  'ago': 401,
#  'htt': 402,
#  'side': 403,
#  'ifb': 404,
#  'cool': 405,
#  'city': 406,
#  'instagram': 407,
#  'straight': 408,
#  'deep': 409,
#  'scene': 410,
#  'snap': 411,
#  'touch': 412,
#  'player': 413,
#  'kind': 414,
#  'g': 415,
#  'ht': 416,
#  'isnt': 417,
#  'respect': 418,
#  'imagine': 419,
#  'late': 420,
#  'preview': 421,
#  'almost': 422,
#  'fake': 423,
#  'lovely': 424,
#  'stand': 425,
#  'queen': 426,
#  'sunday': 427,
#  'feeling': 428,
#  'hole': 429,
#  'everybody': 430,
#  'message': 431,
#  'red': 432,
#  'reach': 433,
#  'set': 434,
#  'party': 435,
#  'shoot': 436,
#  'wtf': 437,
#  'might': 438,
#  'performance': 439,
#  'freestyle': 440,
#  'reason': 441,
#  'agree': 442,
#  'fall': 443,
#  'march': 444,
#  'episode': 445,
#  'chance': 446,
#  'somebody': 447,
#  'wear': 448,
#  'finish': 449,
#  'sell': 450,
#  'thought': 451,
#  'couldnt': 452,
#  'mf': 453,
#  'record': 454,
#  'click': 455,
#  'rn': 456,
#  'register': 457,
#  'da': 458,
#  'female': 459,
#  'men': 460,
#  'america': 461,
#  'dude': 462,
#  'son': 463,
#  'e': 464,
#  'sale': 465,
#  'book': 466,
#  'stream': 467,
#  'hello': 468,
#  'huge': 469,
#  'youve': 470,
#  'dad': 471,
#  'mine': 472,
#  'lord': 473,
#  'min': 474,
#  'trust': 475,
#  'body': 476,
#  'far': 477,
#  'act': 478,
#  'sick': 479,
#  'report': 480,
#  'state': 481,
#  'here': 482,
#  'cum': 483,
#  'class': 484,
#  'throw': 485,
#  'mouth': 486,
#  'wonderful': 487,
#  'sir': 488,
#  'power': 489,
#  'legend': 490,
#  'voting': 491,
#  'there': 492,
#  'strong': 493,
#  'swear': 494,
#  'understand': 495,
#  'iheart': 496,
#  'fine': 497,
#  'l': 498,
#  'p': 499,
#  'snapchat': 500,
#  'tear': 501,
#  'guess': 502,
#  'boyfriend': 503,
#  'rate': 504,
#  'c': 505,
#  'nd': 506,
#  'light': 507,
#  'shipping': 508,
#  'wasnt': 509,
#  'shot': 510,
#  'babe': 511,
#  'online': 512,
#  'bit': 513,
#  'matter': 514,
#  'kick': 515,
#  'hoe': 516,
#  'room': 517,
#  'till': 518,
#  'chat': 519,
#  'sit': 520,
#  'match': 521,
#  'everyday': 522,
#  'less': 523,
#  'cover': 524,
#  'sing': 525,
#  'pass': 526,
#  'behind': 527,
#  'glad': 528,
#  'bruh': 529,
#  'ball': 530,
#  'group': 531,
#  'number': 532,
#  'f': 533,
#  'youll': 534,
#  'notification': 535,
#  'speak': 536,
#  'quick': 537,
#  'youtube': 538,
#  'deal': 539,
#  'answer': 540,
#  'different': 541,
#  'tire': 542,
#  'later': 543,
#  'wit': 544,
#  'voice': 545,
#  'successful': 546,
#  'level': 547,
#  'definitely': 548,
#  'stage': 549,
#  'sometimes': 550,
#  'worth': 551,
#  'maybe': 552,
#  'learn': 553,
#  'em': 554,
#  'bed': 555,
#  'idea': 556,
#  'ticket': 557,
#  'type': 558,
#  'write': 559,
#  'half': 560,
#  'si': 561,
#  'easy': 562,
#  'poor': 563,
#  'alone': 564,
#  'havent': 565,
#  'holy': 566,
#  'worldwide': 567,
#  'yesterday': 568,
#  'daily': 569,
#  'promise': 570,
#  'become': 571,
#  'shop': 572,
#  'mother': 573,
#  'joke': 574,
#  'april': 575,
#  'question': 576,
#  'fuckin': 577,
#  'incredible': 578,
#  'order': 579,
#  'score': 580,
#  'artist': 581,
#  'surprise': 582,
#  'gorgeous': 583,
#  'fam': 584,
#  'lit': 585,
#  'line': 586,
#  'round': 587,
#  'ft': 588,
#  'bull': 589,
#  'mv': 590,
#  'bout': 591,
#  'thread': 592,
#  'amen': 593,
#  'monday': 594,
#  'enter': 595,
#  'wonder': 596,
#  'visit': 597,
#  'difficult': 598,
#  'expect': 599,
#  'block': 600,
#  'ride': 601,
#  'felt': 602,
#  'bag': 603,
#  'democrat': 604,
#  'who': 605,
#  'stuff': 606,
#  'relationship': 607,
#  'drive': 608,
#  'pull': 609,
#  'final': 610,
#  'blessing': 611,
#  'problem': 612,
#  'american': 613,
#  'safe': 614,
#  'early': 615,
#  'gt': 616,
#  'member': 617,
#  'kiss': 618,
#  'fav': 619,
#  'dat': 620,
#  'kst': 621,
#  'continue': 622,
#  'seriously': 623,
#  'chart': 624,
#  'soul': 625,
#  'lucky': 626,
#  'piss': 627,
#  'precious': 628,
#  'ima': 629,
#  'treat': 630,
#  'la': 631,
#  'water': 632,
#  'inside': 633,
#  'brilliant': 634,
#  'rock': 635,
#  'saturday': 636,
#  'complete': 637,
#  'exactly': 638,
#  'small': 639,
#  'anymore': 640,
#  'summer': 641,
#  'site': 642,
#  'happiness': 643,
#  'parent': 644,
#  'human': 645,
#  'asf': 646,
#  'honestly': 647,
#  'receive': 648,
#  'cam': 649,
#  'student': 650,
#  'porn': 651,
#  'horny': 652,
#  'probably': 653,
#  'list': 654,
#  'street': 655,
#  'couple': 656,
#  'tv': 657,
#  'celebrate': 658,
#  'forward': 659,
#  'spot': 660,
#  'truly': 661,
#  'lead': 662,
#  'stupid': 663,
#  'hat': 664,
#  'text': 665,
#  'art': 666,
#  'truth': 667,
#  'mr': 668,
#  'mo': 669,
#  'card': 670,
#  'bet': 671,
#  'case': 672,
#  'wife': 673,
#  'short': 674,
#  'course': 675,
#  'stan': 676,
#  'fucking': 677,
#  'active': 678,
#  'medium': 679,
#  'mate': 680,
#  'item': 681,
#  'bc': 682,
#  'tryna': 683,
#  'self': 684,
#  'future': 685,
#  'chicken': 686,
#  'club': 687,
#  'worry': 688,
#  'snow': 689,
#  'freak': 690,
#  'reaction': 691,
#  'store': 692,
#  'least': 693,
#  'page': 694,
#  'heard': 695,
#  'boat': 696,
#  'niggas': 697,
#  'create': 698,
#  'idk': 699,
#  'cheap': 700,
#  'past': 701,
#  'ppl': 702,
#  'three': 703,
#  'history': 704,
#  'track': 705,
#  'social': 706,
#  'gift': 707,
#  'clean': 708,
#  'gold': 709,
#  'fbi': 710,
#  'hero': 711,
#  'vid': 712,
#  'scream': 713,
#  'drink': 714,
#  'football': 715,
#  'south': 716,
#  'chocolate': 717,
#  'delicious': 718,
#  'important': 719,
#  'available': 720,
#  'chill': 721,
#  'hug': 722,
#  'fat': 723,
#  'drake': 724,
#  'haha': 725,
#  'spring': 726,
#  'tour': 727,
#  'realize': 728,
#  'cheer': 729,
#  'thick': 730,
#  'return': 731,
#  'offer': 732,
#  'bio': 733,
#  'rap': 734,
#  'perform': 735,
#  'spread': 736,
#  'blue': 737,
#  'beauty': 738,
#  'mark': 739,
#  'step': 740,
#  'film': 741,
#  'bday': 742,
#  'taste': 743,
#  'girlfriend': 744,
#  'dumb': 745,
#  'entire': 746,
#  'blood': 747,
#  'app': 748,
#  'park': 749,
#  'crush': 750,
#  'business': 751,
#  'mama': 752,
#  'dinner': 753,
#  'animal': 754,
#  'fr': 755,
#  'dirty': 756,
#  'ion': 757,
#  'outfit': 758,
#  'project': 759,
#  'fortnite': 760,
#  'instead': 761,
#  'hop': 762,
#  'jesus': 763,
#  'wouldnt': 764,
#  'ugly': 765,
#  'rid': 766,
#  'favourite': 767,
#  'begin': 768,
#  'protect': 769,
#  'gap': 770,
#  'fantastic': 771,
#  'po': 772,
#  'jimin': 773,
#  'ice': 774,
#  'de': 775,
#  'able': 776,
#  'uncultured': 777,
#  'cuz': 778,
#  'dress': 779,
#  'college': 780,
#  'public': 781,
#  'father': 782,
#  'air': 783,
#  'front': 784,
#  'buggin': 785,
#  'seem': 786,
#  'code': 787,
#  'destroy': 788,
#  'heartbreaking': 789,
#  'breakfast': 790,
#  'swine': 791,
#  'cat': 792,
#  'build': 793,
#  'skin': 794,
#  'age': 795,
#  'cr': 796,
#  'spongbob': 797,
#  'color': 798,
#  'exols': 799,
#  'sounding': 800,
#  'addict': 801,
#  'rich': 802,
#  'uk': 803,
#  'mess': 804,
#  'remix': 805,
#  'dope': 806,
#  'ronaldo': 807,
#  'choose': 808,
#  'load': 809,
#  'rd': 810,
#  'death': 811,
#  'daughter': 812,
#  'health': 813,
#  'checkout': 814,
#  'sa': 815,
#  'bear': 816,
#  'shut': 817,
#  'serious': 818,
#  'cold': 819,
#  'concert': 820,
#  'gay': 821,
#  'draw': 822,
#  'count': 823,
#  'mention': 824,
#  'kpop': 825,
#  'btsarmy': 826,
#  'band': 827,
#  'wall': 828,
#  'pop': 829,
#  'angel': 830,
#  'cousin': 831,
#  'fly': 832,
#  'angry': 833,
#  'delete': 834,
#  'either': 835,
#  'nasty': 836,
#  'bank': 837,
#  'train': 838,
#  'taehyung': 839,
#  'j': 840,
#  'jungkook': 841,
#  'https': 842,
#  'john': 843,
#  'event': 844,
#  'blow': 845,
#  'credit': 846,
#  'issue': 847,
#  'facebook': 848,
#  'league': 849,
#  'others': 850,
#  'armys': 851,
#  'outside': 852,
#  'attention': 853,
#  'currently': 854,
#  'scar': 855,
#  'cake': 856,
#  'emoji': 857,
#  'double': 858,
#  'yummy': 859,
#  'james': 860,
#  'mic': 861,
#  'cream': 862,
#  'debut': 863,
#  'obama': 864,
#  'ass': 865,
#  'hang': 866,
#  'lunch': 867,
#  'arent': 868,
#  'possible': 869,
#  'insane': 870,
#  'memory': 871,
#  'absolute': 872,
#  'bill': 873,
#  'mass': 874,
#  'booty': 875,
#  'shout': 876,
#  'attack': 877,
#  'weak': 878,
#  'rm': 879,
#  'tuesday': 880,
#  'tune': 881,
#  'jump': 882,
#  'mutiple': 883,
#  'subscribe': 884,
#  'spend': 885,
#  'fix': 886,
#  'plz': 887,
#  'smoke': 888,
#  'announce': 889,
#  'evil': 890,
#  'easter': 891,
#  'smell': 892,
#  'nut': 893,
#  'clinton': 894,
#  'channel': 895,
#  'bomb': 896,
#  'feature': 897,
#  'sooo': 898,
#  'til': 899,
#  'trip': 900,
#  'coach': 901,
#  'wild': 902,
#  'extra': 903,
#  'office': 904,
#  'shock': 905,
#  'officially': 906,
#  'weve': 907,
#  'handle': 908,
#  'stress': 909,
#  'crap': 910,
#  'ate': 911,
#  'bae': 912,
#  'totally': 913,
#  'vibe': 914,
#  'price': 915,
#  'fit': 916,
#  'force': 917,
#  'gun': 918,
#  'exol': 919,
#  'soo': 920,
#  'rise': 921,
#  'interview': 922,
#  'grab': 923,
#  'comeback': 924,
#  'everywhere': 925,
#  'service': 926,
#  'door': 927,
#  'total': 928,
#  'nah': 929,
#  'weather': 930,
#  'focus': 931,
#  'cheat': 932,
#  'session': 933,
#  'bos': 934,
#  'box': 935,
#  'action': 936,
#  'simple': 937,
#  'pure': 938,
#  'knife': 939,
#  'alert': 940,
#  'homie': 941,
#  'xxx': 942,
#  'stick': 943,
#  'success': 944,
#  'hotel': 945,
#  'grateful': 946,
#  'trans': 947,
#  'bar': 948,
#  'broken': 949,
#  'raise': 950,
#  'version': 951,
#  'prize': 952,
#  'road': 953,
#  'mutuals': 954,
#  'test': 955,
#  'war': 956,
#  'handsome': 957,
#  'slow': 958,
#  'meme': 959,
#  'relate': 960,
#  'kinda': 961,
#  'fill': 962,
#  'healthy': 963,
#  'low': 964,
#  'cook': 965,
#  'pas': 966,
#  'allah': 967,
#  'ad': 968,
#  'retweeting': 969,
#  'lay': 970,
#  'wet': 971,
#  'green': 972,
#  'makeup': 973,
#  'paint': 974,
#  'fandom': 975,
#  'heat': 976,
#  'cardi': 977,
#  'positive': 978,
#  'champion': 979,
#  'especially': 980,
#  'key': 981,
#  'cross': 982,
#  'hillary': 983,
#  'deserves': 984,
#  'idc': 985,
#  'experience': 986,
#  'boys': 987,
#  'warm': 988,
#  'fool': 989,
#  'jhope': 990,
#  'suppose': 991,
#  'legit': 992,
#  'fw': 993,
#  'style': 994,
#  'liberal': 995,
#  'patriot': 996,
#  'burn': 997,
#  'decide': 998,
#  'yr': 999,
#  'teacher': 1000,
#  ...}

# %%
len(vocab)
# Out:
# 72636

# %%
vocabulary_size = len(vocab)
seq_len = max_length
embed_len = 128

# BiLSTM + CNN
model = Sequential()
model.add(Embedding(vocabulary_size+1, embed_len, input_length = seq_len))
model.add(Bidirectional(LSTM(128,return_sequences=True)))
model.add(Conv1D(128, 3, padding = 'same', activation = 'relu'))
model.add(MaxPooling1D())
model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dense(total_emoji_number, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 34, 128)           9297536
#
#  bidirectional_2 (Bidirectio  (None, 34, 256)          263168
#  nal)
#
#  conv1d_14 (Conv1D)          (None, 34, 128)           98432
#
#  max_pooling1d_13 (MaxPoolin  (None, 17, 128)          0
#  g1D)
#
#  flatten_5 (Flatten)         (None, 2176)              0
#
#  dense_22 (Dense)            (None, 64)                139328
#
#  dense_23 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 9,799,439
# Trainable params: 9,799,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor="val_loss", mode="min", patience=1,verbose=1)
model.compile(loss = 'categorical_crossentropy',
             optimizer = "adam",
             metrics=["accuracy"])

# %%
from keras.utils import to_categorical

train_Y_cat = to_categorical(train_Y)
test_Y_cat = to_categorical(test_Y)
print(train_Y_cat.shape)
print(test_Y_cat.shape)
# Out:
# (156729, 15)
# (67131, 15)

# %%
batch_size=64
epochs = 10

model.fit(train_X, train_Y_cat, batch_size=batch_size, epochs = epochs, 
          shuffle=True,validation_data=(test_X, test_Y_cat), callbacks=[early_stop]) #, callbacks=[early_stop]
# Out:
# Epoch 1/10
# 2449/2449 [==============================] - 741s 300ms/step - loss: 2.2051 - accuracy: 0.2949 - val_loss: 2.0074 - val_accuracy: 0.3691
# Epoch 2/10
# 2449/2449 [==============================] - 791s 323ms/step - loss: 1.7671 - accuracy: 0.4510 - val_loss: 1.9709 - val_accuracy: 0.3940
# Epoch 3/10
# 2449/2449 [==============================] - 806s 329ms/step - loss: 1.4447 - accuracy: 0.5543 - val_loss: 2.0680 - val_accuracy: 0.3993
# Epoch 3: early stopping

# %%
model.evaluate(test_X, test_Y_cat, batch_size=batch_size)
# Out:
# 1049/1049 [==============================] - 51s 48ms/step - loss: 2.0680 - accuracy: 0.3993
# [2.0679867267608643, 0.39930880069732666]

# %%
from sklearn.metrics import classification_report, confusion_matrix

predictions_prob = model.predict(test_X)
print(predictions_prob)
print(len(predictions_prob))
print(len(predictions_prob[0]))
# Out:
# 2098/2098 [==============================] - 56s 26ms/step
# [[1.5196457e-02 6.1541460e-02 1.5251780e-02 ... 8.2372099e-02
#   3.0231627e-02 1.7154953e-02]
#  [1.0971610e-02 1.2430697e-02 5.6438972e-03 ... 8.2265741e-01
#   4.0150858e-03 2.9196304e-03]
#  [4.2747558e-07 2.5663510e-06 1.2061287e-07 ... 9.9996316e-01
#   5.7606048e-08 2.7879230e-07]
#  ...
#  [2.5504109e-02 1.2736737e-02 7.1764201e-01 ... 8.8178962e-03
#   2.3465339e-02 1.2556900e-02]
#  [5.9993146e-03 6.9385208e-03 1.1744396e-03 ... 4.4401750e-01
#   3.5872397e-03 3.5443180e-03]
#  [1.3302633e-07 2.6804639e-09 8.7940386e-08 ... 1.5679027e-09
#   7.7073409e-08 7.1999438e-08]]
# 67131
# 15

# %%
# model.save("BLSTM.2")

# %%
# Get the predicted emoji class
test_Y_pred = np.argmax(model.predict(test_X), axis=-1)
# Out:
# 2098/2098 [==============================] - 48s 23ms/step

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report
print(classification_report(test_Y, test_Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.35      0.28      4462
#            1       0.29      0.33      0.31      4386
#            2       0.49      0.45      0.47      4466
#            3       0.27      0.36      0.31      4501
#            4       0.34      0.25      0.29      4513
#            5       0.37      0.22      0.28      4514
#            6       0.36      0.39      0.37      4504
#            7       0.39      0.44      0.41      4458
#            8       0.55      0.43      0.48      4370
#            9       0.51      0.52      0.51      4426
#           10       0.48      0.43      0.45      4468
#           11       0.52      0.64      0.57      4508
#           12       0.44      0.42      0.43      4532
#           13       0.44      0.34      0.38      4452
#           14       0.48      0.42      0.45      4571
#
#     accuracy                           0.40     67131
#    macro avg       0.41      0.40      0.40     67131
# weighted avg       0.41      0.40      0.40     67131

# %% [markdown]
# # Emoji Recommender Top k Evaluation

# %%
def top_k_prediction(prob, k):
    results = []
    for item in prob:
        # Create a copy of the original array to avoid modifying it
        arr_copy = item.copy()

        # Get the indices that would sort the array in ascending order
        sorted_indices = np.argsort(arr_copy)

        # Take the last 5 indices to get the indices of the top 5 elements
        top_indices = sorted_indices[-k:]
        
        results.append(top_indices)
        
    return results

# %%
result = test_df.copy()
top_3_predictions = top_k_prediction(predictions_prob, 3)
result["predict_emoji_3"] = top_3_predictions
result["predict_accurate_3"] = result.apply(lambda x: x.emoji_id in x.predict_emoji_3, axis = 1)

# %%
# Top 3 accuracy - overall score
print(len(result[result["predict_accurate_3"] == 1]) / len(result))
# Out:
# 0.6192965991866649

# %%
result["count"] = 1
result_top_3_aggregated = pd.DataFrame()
result_top_3_aggregated["emoji_id"] = result.groupby("emoji_id")['predict_accurate_3'].sum().index.astype('str')
result_top_3_aggregated["count"] = result.groupby("emoji_id")['count'].sum().values
result_top_3_aggregated["accurate predictions"] = result.groupby("emoji_id")['predict_accurate_3'].sum().values
result_top_3_aggregated = result_top_3_aggregated.sort_values('accurate predictions', ascending = False)
result_top_3_aggregated["accuracy"] = result_top_3_aggregated["accurate predictions"] / result_top_3_aggregated["count"]
result_top_3_aggregated["emoji_id"] = pd.to_numeric(result_top_3_aggregated["emoji_id"])
result_top_3_aggregated = result_top_3_aggregated.sort_values(by=['emoji_id'])
result_top_3_aggregated
# Out:
#     emoji_id  count  accurate predictions  accuracy
# 0          0   4462                  2839  0.636262
# 1          1   4386                  2582  0.588691
# 2          2   4466                  2625  0.587774
# 3          3   4501                  2982  0.662519
# 4          4   4513                  2532  0.561046
# 5          5   4514                  2553  0.565574
# 6          6   4504                  2767  0.614343
# 7          7   4458                  2937  0.658816
# 8          8   4370                  2512  0.574828
# 9          9   4426                  2962  0.669227
# 10        10   4468                  2891  0.647046
# 11        11   4508                  3373  0.748225
# 12        12   4532                  2723  0.600838
# 13        13   4452                  2441  0.548293
# 14        14   4571                  2855  0.624590

# %%
import matplotlib.pyplot as plt

x = result_top_3_aggregated["emoji_id"]
y = result_top_3_aggregated["accuracy"]

# Create the bar chart using the bar function
plt.bar(x, y)

# Add a title and axis labels
plt.title('Top 3 Accuracy by Emoji')
plt.xlabel('Emoji ID')
plt.ylabel('Accuracy')

# Display the plot
plt.show()

# %%
from sklearn.metrics import confusion_matrix
df_cm = pd.DataFrame(confusion_matrix(all_df["emoji_id"].values[split_index:], test_Y_pred))
import seaborn as sn
plt.figure(figsize = (10, 10))
sn.heatmap(df_cm, annot = True, fmt = 'd')
plt.show()
