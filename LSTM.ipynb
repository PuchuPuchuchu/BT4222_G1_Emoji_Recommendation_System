# %%
import pandas as pd
import numpy as np
import emoji
import nltk
import ssl

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Emoji-related functions

# %%
def emojiname2icon(name):
    return emoji.emojize(f":{name.replace(' ','_')}:")

emojiname2icon('smiling face with hearts')
# Out:
# '🥰'

# %% [markdown]
# ## Function: Remove special characters

# %%
import re

def remove_special(text):
    # Remove URLs
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = url_pattern.sub('', text)
    
    # Remove words starting with # and @ for all languages
    hashtag_pattern = re.compile(r'(?:^|\s)[@#](?:\w+|[^\s\w])+')
    text = hashtag_pattern.sub('', text)
    
    # Remove punctuation
    punctuation_pattern = re.compile(r'[^\w\s]', re.UNICODE)
    text = punctuation_pattern.sub('', text)
    

    # Remove emoji, number, tab
    emoji_number_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"0-9"           # numbers
        u"\n\t"           # newline and tab characters

                           "]+", flags=re.UNICODE)
    text = emoji_number_pattern.sub(r'', text)

    return text

remove_special('💋💫😀\nProduction appear product door 1234')
# Out:
# 'Production appear product door '

# %% [markdown]
# ## Function: Remove stop words and lemmatization

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('averaged_perceptron_tagger')
  
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def remove_stopword_and_lemmatized(text):
    #tokenized and change to lower
    word_tokens = word_tokenize(text.lower())

    #remove stop word
    filtered_sentence = [w for w in word_tokens if not w in stop_words]

    #get part of speech
    pos = nltk.pos_tag(filtered_sentence)

    #lemmatization with POS
    lemmeanized_sentence = [lemmatizer.lemmatize(filtered_sentence[i],get_wordnet_pos(pos[i][1])) if get_wordnet_pos(pos[i][1]) != None else lemmatizer.lemmatize(filtered_sentence[i]) for i in range(len(filtered_sentence))]

    #remove duplicates (in order)
    return " ".join(list(dict.fromkeys(lemmeanized_sentence)))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Function: Apply preprocessing functions

# %%
def content_preprocessing(df):
    df['cleaned content'] = df['content'].apply(remove_special)
    df['cleaned_content'] = df['cleaned content'].apply(remove_stopword_and_lemmatized)
    
    #get emoji id for name
    df['emoji_id'] = df['emoji_name'].apply(lambda name: emojiname2id_dic[name])
    
    return df[['emoji_id','content','cleaned_content']]

# %% [markdown]
# ## Combine data from different data sources

# %%
#Produce Emoji_DF[emoji_id, emoji_name]
top_20_emoji_name = [

    'face with tears of joy', # funny happy
    
    'red heart', #love
    
    'broken heart', #no love
    
    'thumbs up', #encouragement
    
    'smiling face with smiling eyes', #happy
    
    'loudly crying face', #pure sad
    
    'clapping hands', #congradualation
    
    'fire', #hot /sexy
    
    'face screaming in fear', #shock
    
    'pile of poo', #non-sense, disapproval
    
    'face with symbols on mouth', #anger
    
    'eggplant', #horny
    
    'face savoring food', # craving
    
    'hundred points', #approval
    
    'folded hands', #pray
    
]

emoji_reference = {'emoji_name':top_20_emoji_name,'emoji_id':[i for i in range(len(top_20_emoji_name))]}
emoji_df =  pd.DataFrame(emoji_reference)
emoji_df

emojiname2id_dic = {emoji_df.emoji_name[i]:emoji_df.index[i] for i in range(len(emoji_df.index))}
emojiid2name_dic = {emoji_df.index[i]:emoji_df.emoji_name[i] for i in range(len(emoji_df.index))}

# load data from different data source
scrape1 = pd.read_csv('processed_data.csv', index_col = 0)
scrape2 = pd.read_csv('processed_data_batch2.csv')

df = pd.DataFrame(columns=['emoji_name','emoji','content','cleaned content'])
df = pd.concat([df,scrape1,scrape2])
top_20_emoji_df = pd.DataFrame(columns=['emoji_name','emoji','content','cleaned content'])
for name in top_20_emoji_name:
    top_20_emoji_df = pd.concat([top_20_emoji_df,df[df.emoji_name==name]])

kaggle_tweets = pd.read_csv('kaggle_tweets 15 selected emoji.csv',names=['emoji_name','content'])

# %%
# Concat everything togehter 
total_df = pd.concat([top_20_emoji_df,kaggle_tweets])
total_df
# Out:
#                      emoji_name emoji  \
# 47       face with tears of joy     😂
# 206      face with tears of joy     😂
# 386      face with tears of joy     😂
# 426      face with tears of joy     😂
# 454      face with tears of joy     😂
# ...                         ...   ...
# 7390713      loudly crying face   NaN
# 7390714  face with tears of joy   NaN
# 7390715      loudly crying face   NaN
# 7390716          clapping hands   NaN
# 7390717  face with tears of joy   NaN
#
#                                                    content  \
# 47                      @PeakSanti But why this photo?😀😀😂😂
# 206      @Sachin_Ro45 Mass troll 😀😀😀😀😂😂😂😂😂😂\n@AdnanSami...
# 386      The people I work with thinks the bank has all...
# 426             @Jamespa97888596 😂😂😂 all friends again 👌👌😀
# 454      How you so in love with a nigga that's never w...
# ...                                                    ...
# 7390713  &amp; to think I was going to split my tax ref...
# 7390714  &amp; to think I was going to split my tax ref...
# 7390715  please !! remove the suspension from the pleas...
# 7390716  please. 👏🏼 so because i stan someone means i d...
# 7390717  please. 👏🏼 so because i stan someone means i d...
#
#                                            cleaned content
# 47                                 But why this photo?😀😀😂😂
# 206           Mass troll 😀😀😀😀😂😂😂😂😂😂\n plz watch this video
# 386      The people I work with thinks the bank has all...
# 426                              😂😂😂 all friends again 👌👌😀
# 454      How you so in love with a nigga that's never w...
# ...                                                    ...
# 7390713                                                NaN
# 7390714                                                NaN
# 7390715                                                NaN
# 7390716                                                NaN
# 7390717                                                NaN
#
# [7492030 rows x 4 columns]

# %% [markdown]
# ## Sampled training and testing data from combined data

# %%
def get_n_sample(df, n, random_state):
    sample_data =  pd.DataFrame()
    for name in top_20_emoji_name:
        sample = df[df.emoji_name == name].sample(n=n,  random_state=random_state)
        sample_data = pd.concat([sample_data,sample])
    return sample_data

# %%
# randomly sampled from total df for tarining and testing 
from sklearn.model_selection import train_test_split

# Change sample size to 10000 from 8000; test_size changed to 0.2 from 0,4
train, test = train_test_split(get_n_sample(total_df,15000,4222), test_size=0.3,random_state=4222)

# apply data preprocessing on selected content
train_df, test_df = content_preprocessing(train), content_preprocessing(test)

# %%
# remove trained data with cleaned content > 0 words
train_df['cleaned_content_len']= train_df.cleaned_content.apply(lambda x: len(x.split()))
test_df['cleaned_content_len']= test_df.cleaned_content.apply(lambda x: len(x.split()))
train_df, test_df  = train_df[train_df.cleaned_content_len >=1],test_df[test_df.cleaned_content_len >=1]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7728\3036399428.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['cleaned_content_len']= train_df.cleaned_content.apply(lambda x: len(x.split()))
# C:\Users\user\AppData\Local\Temp\ipykernel_7728\3036399428.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['cleaned_content_len']= test_df.cleaned_content.apply(lambda x: len(x.split()))

# %% [markdown]
# # LSTM

# %%
# !pip install --upgrade pip
# !pip install tensorflow

import random
import tensorflow as tf
import tensorflow.keras
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.utils import to_categorical
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dropout, Dense, LSTM, Embedding
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
random.seed(4222)
emoji_shuffled = shuffle(emoji_df)
print(emoji_shuffled)
# Out:
#                         emoji_name  emoji_id
# 2                     broken heart         2
# 4   smiling face with smiling eyes         4
# 11                        eggplant        11
# 3                        thumbs up         3
# 6                   clapping hands         6
# 13                  hundred points        13
# 12              face savoring food        12
# 5               loudly crying face         5
# 7                             fire         7
# 0           face with tears of joy         0
# 8           face screaming in fear         8
# 1                        red heart         1
# 14                    folded hands        14
# 9                      pile of poo         9
# 10      face with symbols on mouth        10

# %%
split_index = len(train_df)
total_emoji_number = len(emoji_df)

# %%
# COMBINING 

df = pd.concat([train_df, test_df])

X = df["cleaned_content"].values
y = pd.get_dummies(df["emoji_id"].values)

tokenizer = Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', split=" ", lower=True)
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)
X_pad = pad_sequences(X_seq, truncating = "pre", padding = "pre", maxlen = 40)

X_train = X_pad[:split_index]
y_train = y[:split_index]
X_test = X_pad[split_index:]
y_test = y[split_index:]

# %%
word2index = tokenizer.word_index
word2index
# Out:
# {'get': 1,
#  'like': 2,
#  'im': 3,
#  'love': 4,
#  'amp': 5,
#  'go': 6,
#  'good': 7,
#  'u': 8,
#  'day': 9,
#  'dont': 10,
#  'make': 11,
#  'follow': 12,
#  'one': 13,
#  'see': 14,
#  'thank': 15,
#  'retweet': 16,
#  'back': 17,
#  'time': 18,
#  'new': 19,
#  'happy': 20,
#  'want': 21,
#  'know': 22,
#  'rt': 23,
#  'look': 24,
#  'need': 25,
#  'say': 26,
#  'come': 27,
#  'please': 28,
#  'let': 29,
#  'cant': 30,
#  'today': 31,
#  'take': 32,
#  'best': 33,
#  'much': 34,
#  'well': 35,
#  'fuck': 36,
#  'year': 37,
#  'shit': 38,
#  'everyone': 39,
#  'video': 40,
#  'people': 41,
#  'think': 42,
#  'really': 43,
#  'man': 44,
#  'god': 45,
#  'watch': 46,
#  'great': 47,
#  'na': 48,
#  'tweet': 49,
#  'never': 50,
#  'guy': 51,
#  'give': 52,
#  'still': 53,
#  'life': 54,
#  'keep': 55,
#  'yall': 56,
#  'girl': 57,
#  'right': 58,
#  'big': 59,
#  'work': 60,
#  'always': 61,
#  'miss': 62,
#  'thanks': 63,
#  'thing': 64,
#  'thats': 65,
#  'feel': 66,
#  'even': 67,
#  'youre': 68,
#  'friend': 69,
#  'help': 70,
#  'last': 71,
#  'ever': 72,
#  'wait': 73,
#  'luck': 74,
#  'first': 75,
#  'http': 76,
#  'heart': 77,
#  'way': 78,
#  'free': 79,
#  'show': 80,
#  'second': 81,
#  'baby': 82,
#  'birthday': 83,
#  'real': 84,
#  'would': 85,
#  'hope': 86,
#  'omg': 87,
#  'start': 88,
#  'live': 89,
#  'boy': 90,
#  'oh': 91,
#  'vote': 92,
#  'gain': 93,
#  'play': 94,
#  'fan': 95,
#  'every': 96,
#  'try': 97,
#  'tell': 98,
#  'song': 99,
#  'morning': 100,
#  'week': 101,
#  'use': 102,
#  'find': 103,
#  'nigga': 104,
#  'as': 105,
#  'win': 106,
#  'k': 107,
#  'night': 108,
#  'break': 109,
#  'stop': 110,
#  'do': 111,
#  'call': 112,
#  'beautiful': 113,
#  'bad': 114,
#  'everything': 115,
#  'another': 116,
#  'someone': 117,
#  'game': 118,
#  'dick': 119,
#  'hard': 120,
#  'ill': 121,
#  'next': 122,
#  'army': 123,
#  'hour': 124,
#  'full': 125,
#  'leave': 126,
#  'talk': 127,
#  'aint': 128,
#  'follower': 129,
#  'bitch': 130,
#  'wan': 131,
#  'bless': 132,
#  'gon': 133,
#  'end': 134,
#  'world': 135,
#  'tonight': 136,
#  'music': 137,
#  'wow': 138,
#  'ive': 139,
#  'yes': 140,
#  'little': 141,
#  'cry': 142,
#  'th': 143,
#  'put': 144,
#  'wish': 145,
#  'twitter': 146,
#  'could': 147,
#  'ready': 148,
#  'check': 149,
#  'old': 150,
#  'support': 151,
#  'drop': 152,
#  'lose': 153,
#  'family': 154,
#  'trump': 155,
#  'nice': 156,
#  'retweets': 157,
#  'lol': 158,
#  'he': 159,
#  'damn': 160,
#  'proud': 161,
#  'hate': 162,
#  'home': 163,
#  'kid': 164,
#  'sex': 165,
#  'turn': 166,
#  'sure': 167,
#  'cute': 168,
#  'didnt': 169,
#  'yo': 170,
#  'soon': 171,
#  'congratulation': 172,
#  'hot': 173,
#  'woman': 174,
#  'away': 175,
#  'team': 176,
#  'post': 177,
#  'bro': 178,
#  'many': 179,
#  'hit': 180,
#  'sound': 181,
#  'stay': 182,
#  'happen': 183,
#  'send': 184,
#  'enjoy': 185,
#  'mean': 186,
#  'kill': 187,
#  'lot': 188,
#  'ask': 189,
#  'black': 190,
#  'part': 191,
#  'already': 192,
#  'something': 193,
#  'lil': 194,
#  'hear': 195,
#  'goal': 196,
#  'via': 197,
#  'tomorrow': 198,
#  'amaze': 199,
#  'x': 200,
#  'top': 201,
#  'school': 202,
#  'believe': 203,
#  'bts': 204,
#  'fast': 205,
#  'eat': 206,
#  'money': 207,
#  'two': 208,
#  'listen': 209,
#  'face': 210,
#  'w': 211,
#  'nothing': 212,
#  'long': 213,
#  'ya': 214,
#  'congrats': 215,
#  'word': 216,
#  'ta': 217,
#  'may': 218,
#  'reply': 219,
#  'shes': 220,
#  'fire': 221,
#  'finally': 222,
#  'job': 223,
#  'run': 224,
#  'smile': 225,
#  'name': 226,
#  'dm': 227,
#  'month': 228,
#  'whole': 229,
#  'hey': 230,
#  'share': 231,
#  'remember': 232,
#  'true': 233,
#  'person': 234,
#  'album': 235,
#  'also': 236,
#  'die': 237,
#  'since': 238,
#  'care': 239,
#  'season': 240,
#  'b': 241,
#  'rts': 242,
#  'fun': 243,
#  'save': 244,
#  'around': 245,
#  'cause': 246,
#  'doesnt': 247,
#  'n': 248,
#  'change': 249,
#  'forget': 250,
#  'sorry': 251,
#  'high': 252,
#  'join': 253,
#  'h': 254,
#  'update': 255,
#  'pic': 256,
#  'must': 257,
#  'brother': 258,
#  'wont': 259,
#  'ur': 260,
#  'hell': 261,
#  'together': 262,
#  'bring': 263,
#  'minute': 264,
#  'head': 265,
#  'pay': 266,
#  'meet': 267,
#  'welcome': 268,
#  'deserve': 269,
#  'rip': 270,
#  'lie': 271,
#  'crazy': 272,
#  'exo': 273,
#  'super': 274,
#  'giveaway': 275,
#  'without': 276,
#  'sweet': 277,
#  'mom': 278,
#  'pray': 279,
#  'suck': 280,
#  'story': 281,
#  'comment': 282,
#  'read': 283,
#  'sleep': 284,
#  'literally': 285,
#  'winner': 286,
#  'buy': 287,
#  'pm': 288,
#  'weekend': 289,
#  'dog': 290,
#  'piece': 291,
#  'young': 292,
#  'funny': 293,
#  'trend': 294,
#  'account': 295,
#  'pretty': 296,
#  'news': 297,
#  'walk': 298,
#  'hurt': 299,
#  'valentine': 300,
#  'dear': 301,
#  'open': 302,
#  'child': 303,
#  'peace': 304,
#  'move': 305,
#  'favorite': 306,
#  'picture': 307,
#  'yeah': 308,
#  'link': 309,
#  'moment': 310,
#  'million': 311,
#  'anything': 312,
#  'v': 313,
#  'enough': 314,
#  'awesome': 315,
#  'cock': 316,
#  'hand': 317,
#  'tf': 318,
#  'tag': 319,
#  'dream': 320,
#  'forever': 321,
#  'rest': 322,
#  'anyone': 323,
#  'point': 324,
#  'car': 325,
#  'appreciate': 326,
#  'pick': 327,
#  'actually': 328,
#  'food': 329,
#  'st': 330,
#  'theyre': 331,
#  'sister': 332,
#  'prayer': 333,
#  'pain': 334,
#  'ok': 335,
#  'challenge': 336,
#  'photo': 337,
#  'hi': 338,
#  'mad': 339,
#  'perfect': 340,
#  'sad': 341,
#  'view': 342,
#  'tho': 343,
#  'dance': 344,
#  'wrong': 345,
#  'lady': 346,
#  'wake': 347,
#  'ig': 348,
#  'whats': 349,
#  'phone': 350,
#  'hair': 351,
#  'pussy': 352,
#  'amazing': 353,
#  'cut': 354,
#  'white': 355,
#  'sexy': 356,
#  'beat': 357,
#  'fight': 358,
#  'place': 359,
#  'af': 360,
#  'single': 361,
#  'house': 362,
#  'release': 363,
#  'r': 364,
#  'okay': 365,
#  'dead': 366,
#  'movie': 367,
#  'else': 368,
#  'eye': 369,
#  'date': 370,
#  'star': 371,
#  'nobody': 372,
#  'yet': 373,
#  'official': 374,
#  'lmao': 375,
#  'though': 376,
#  'id': 377,
#  'friday': 378,
#  'special': 379,
#  'mind': 380,
#  'hold': 381,
#  'absolutely': 382,
#  'close': 383,
#  'award': 384,
#  'laugh': 385,
#  'catch': 386,
#  'king': 387,
#  'fact': 388,
#  'excite': 389,
#  'plan': 390,
#  'sign': 391,
#  'add': 392,
#  'grow': 393,
#  'mood': 394,
#  'daddy': 395,
#  'country': 396,
#  'president': 397,
#  'roll': 398,
#  'saw': 399,
#  'pls': 400,
#  'ago': 401,
#  'htt': 402,
#  'side': 403,
#  'ifb': 404,
#  'cool': 405,
#  'city': 406,
#  'instagram': 407,
#  'straight': 408,
#  'deep': 409,
#  'scene': 410,
#  'snap': 411,
#  'touch': 412,
#  'player': 413,
#  'kind': 414,
#  'g': 415,
#  'ht': 416,
#  'isnt': 417,
#  'respect': 418,
#  'imagine': 419,
#  'late': 420,
#  'preview': 421,
#  'almost': 422,
#  'fake': 423,
#  'lovely': 424,
#  'stand': 425,
#  'queen': 426,
#  'sunday': 427,
#  'feeling': 428,
#  'hole': 429,
#  'everybody': 430,
#  'message': 431,
#  'red': 432,
#  'reach': 433,
#  'set': 434,
#  'party': 435,
#  'shoot': 436,
#  'wtf': 437,
#  'might': 438,
#  'performance': 439,
#  'freestyle': 440,
#  'reason': 441,
#  'agree': 442,
#  'fall': 443,
#  'march': 444,
#  'episode': 445,
#  'chance': 446,
#  'somebody': 447,
#  'wear': 448,
#  'finish': 449,
#  'sell': 450,
#  'thought': 451,
#  'couldnt': 452,
#  'mf': 453,
#  'record': 454,
#  'click': 455,
#  'rn': 456,
#  'register': 457,
#  'da': 458,
#  'female': 459,
#  'men': 460,
#  'america': 461,
#  'dude': 462,
#  'son': 463,
#  'e': 464,
#  'sale': 465,
#  'book': 466,
#  'stream': 467,
#  'hello': 468,
#  'huge': 469,
#  'youve': 470,
#  'dad': 471,
#  'mine': 472,
#  'lord': 473,
#  'min': 474,
#  'trust': 475,
#  'body': 476,
#  'far': 477,
#  'act': 478,
#  'sick': 479,
#  'report': 480,
#  'state': 481,
#  'here': 482,
#  'cum': 483,
#  'class': 484,
#  'throw': 485,
#  'mouth': 486,
#  'wonderful': 487,
#  'sir': 488,
#  'power': 489,
#  'legend': 490,
#  'voting': 491,
#  'there': 492,
#  'strong': 493,
#  'swear': 494,
#  'understand': 495,
#  'iheart': 496,
#  'fine': 497,
#  'l': 498,
#  'p': 499,
#  'snapchat': 500,
#  'tear': 501,
#  'guess': 502,
#  'boyfriend': 503,
#  'rate': 504,
#  'c': 505,
#  'nd': 506,
#  'light': 507,
#  'shipping': 508,
#  'wasnt': 509,
#  'shot': 510,
#  'babe': 511,
#  'online': 512,
#  'bit': 513,
#  'matter': 514,
#  'kick': 515,
#  'hoe': 516,
#  'room': 517,
#  'till': 518,
#  'chat': 519,
#  'sit': 520,
#  'match': 521,
#  'everyday': 522,
#  'less': 523,
#  'cover': 524,
#  'sing': 525,
#  'pass': 526,
#  'behind': 527,
#  'glad': 528,
#  'bruh': 529,
#  'ball': 530,
#  'group': 531,
#  'number': 532,
#  'f': 533,
#  'youll': 534,
#  'notification': 535,
#  'speak': 536,
#  'quick': 537,
#  'youtube': 538,
#  'deal': 539,
#  'answer': 540,
#  'different': 541,
#  'tire': 542,
#  'later': 543,
#  'wit': 544,
#  'voice': 545,
#  'successful': 546,
#  'level': 547,
#  'definitely': 548,
#  'stage': 549,
#  'sometimes': 550,
#  'worth': 551,
#  'maybe': 552,
#  'learn': 553,
#  'em': 554,
#  'bed': 555,
#  'idea': 556,
#  'ticket': 557,
#  'type': 558,
#  'write': 559,
#  'half': 560,
#  'si': 561,
#  'easy': 562,
#  'poor': 563,
#  'alone': 564,
#  'havent': 565,
#  'holy': 566,
#  'worldwide': 567,
#  'yesterday': 568,
#  'daily': 569,
#  'promise': 570,
#  'become': 571,
#  'shop': 572,
#  'mother': 573,
#  'joke': 574,
#  'april': 575,
#  'question': 576,
#  'fuckin': 577,
#  'incredible': 578,
#  'order': 579,
#  'score': 580,
#  'artist': 581,
#  'surprise': 582,
#  'gorgeous': 583,
#  'fam': 584,
#  'lit': 585,
#  'line': 586,
#  'round': 587,
#  'ft': 588,
#  'bull': 589,
#  'mv': 590,
#  'bout': 591,
#  'thread': 592,
#  'amen': 593,
#  'monday': 594,
#  'enter': 595,
#  'wonder': 596,
#  'visit': 597,
#  'difficult': 598,
#  'expect': 599,
#  'block': 600,
#  'ride': 601,
#  'felt': 602,
#  'bag': 603,
#  'democrat': 604,
#  'who': 605,
#  'stuff': 606,
#  'relationship': 607,
#  'drive': 608,
#  'pull': 609,
#  'final': 610,
#  'blessing': 611,
#  'problem': 612,
#  'american': 613,
#  'safe': 614,
#  'early': 615,
#  'gt': 616,
#  'member': 617,
#  'kiss': 618,
#  'fav': 619,
#  'dat': 620,
#  'kst': 621,
#  'continue': 622,
#  'seriously': 623,
#  'chart': 624,
#  'soul': 625,
#  'lucky': 626,
#  'piss': 627,
#  'precious': 628,
#  'ima': 629,
#  'treat': 630,
#  'la': 631,
#  'water': 632,
#  'inside': 633,
#  'brilliant': 634,
#  'rock': 635,
#  'saturday': 636,
#  'complete': 637,
#  'exactly': 638,
#  'small': 639,
#  'anymore': 640,
#  'summer': 641,
#  'site': 642,
#  'happiness': 643,
#  'parent': 644,
#  'human': 645,
#  'asf': 646,
#  'honestly': 647,
#  'receive': 648,
#  'cam': 649,
#  'student': 650,
#  'porn': 651,
#  'horny': 652,
#  'probably': 653,
#  'list': 654,
#  'street': 655,
#  'couple': 656,
#  'tv': 657,
#  'celebrate': 658,
#  'forward': 659,
#  'spot': 660,
#  'truly': 661,
#  'lead': 662,
#  'stupid': 663,
#  'hat': 664,
#  'text': 665,
#  'art': 666,
#  'truth': 667,
#  'mr': 668,
#  'mo': 669,
#  'card': 670,
#  'bet': 671,
#  'case': 672,
#  'wife': 673,
#  'short': 674,
#  'course': 675,
#  'stan': 676,
#  'fucking': 677,
#  'active': 678,
#  'medium': 679,
#  'mate': 680,
#  'item': 681,
#  'bc': 682,
#  'tryna': 683,
#  'self': 684,
#  'future': 685,
#  'chicken': 686,
#  'club': 687,
#  'worry': 688,
#  'snow': 689,
#  'freak': 690,
#  'reaction': 691,
#  'store': 692,
#  'least': 693,
#  'page': 694,
#  'heard': 695,
#  'boat': 696,
#  'niggas': 697,
#  'create': 698,
#  'idk': 699,
#  'cheap': 700,
#  'past': 701,
#  'ppl': 702,
#  'three': 703,
#  'history': 704,
#  'track': 705,
#  'social': 706,
#  'gift': 707,
#  'clean': 708,
#  'gold': 709,
#  'fbi': 710,
#  'hero': 711,
#  'vid': 712,
#  'scream': 713,
#  'drink': 714,
#  'football': 715,
#  'south': 716,
#  'chocolate': 717,
#  'delicious': 718,
#  'important': 719,
#  'available': 720,
#  'chill': 721,
#  'hug': 722,
#  'fat': 723,
#  'drake': 724,
#  'haha': 725,
#  'spring': 726,
#  'tour': 727,
#  'realize': 728,
#  'cheer': 729,
#  'thick': 730,
#  'return': 731,
#  'offer': 732,
#  'bio': 733,
#  'rap': 734,
#  'perform': 735,
#  'spread': 736,
#  'blue': 737,
#  'beauty': 738,
#  'mark': 739,
#  'step': 740,
#  'film': 741,
#  'bday': 742,
#  'taste': 743,
#  'girlfriend': 744,
#  'dumb': 745,
#  'entire': 746,
#  'blood': 747,
#  'app': 748,
#  'park': 749,
#  'crush': 750,
#  'business': 751,
#  'mama': 752,
#  'dinner': 753,
#  'animal': 754,
#  'fr': 755,
#  'dirty': 756,
#  'ion': 757,
#  'outfit': 758,
#  'project': 759,
#  'fortnite': 760,
#  'instead': 761,
#  'hop': 762,
#  'jesus': 763,
#  'wouldnt': 764,
#  'ugly': 765,
#  'rid': 766,
#  'favourite': 767,
#  'begin': 768,
#  'protect': 769,
#  'gap': 770,
#  'fantastic': 771,
#  'po': 772,
#  'jimin': 773,
#  'ice': 774,
#  'de': 775,
#  'able': 776,
#  'uncultured': 777,
#  'cuz': 778,
#  'dress': 779,
#  'college': 780,
#  'public': 781,
#  'father': 782,
#  'air': 783,
#  'front': 784,
#  'buggin': 785,
#  'seem': 786,
#  'code': 787,
#  'destroy': 788,
#  'heartbreaking': 789,
#  'breakfast': 790,
#  'swine': 791,
#  'cat': 792,
#  'build': 793,
#  'skin': 794,
#  'age': 795,
#  'cr': 796,
#  'spongbob': 797,
#  'color': 798,
#  'exols': 799,
#  'sounding': 800,
#  'addict': 801,
#  'rich': 802,
#  'uk': 803,
#  'mess': 804,
#  'remix': 805,
#  'dope': 806,
#  'ronaldo': 807,
#  'choose': 808,
#  'load': 809,
#  'rd': 810,
#  'death': 811,
#  'daughter': 812,
#  'health': 813,
#  'checkout': 814,
#  'sa': 815,
#  'bear': 816,
#  'shut': 817,
#  'serious': 818,
#  'cold': 819,
#  'concert': 820,
#  'gay': 821,
#  'draw': 822,
#  'count': 823,
#  'mention': 824,
#  'kpop': 825,
#  'btsarmy': 826,
#  'band': 827,
#  'wall': 828,
#  'pop': 829,
#  'angel': 830,
#  'cousin': 831,
#  'fly': 832,
#  'angry': 833,
#  'delete': 834,
#  'either': 835,
#  'nasty': 836,
#  'bank': 837,
#  'train': 838,
#  'taehyung': 839,
#  'j': 840,
#  'jungkook': 841,
#  'https': 842,
#  'john': 843,
#  'event': 844,
#  'blow': 845,
#  'credit': 846,
#  'issue': 847,
#  'facebook': 848,
#  'league': 849,
#  'others': 850,
#  'armys': 851,
#  'outside': 852,
#  'attention': 853,
#  'currently': 854,
#  'scar': 855,
#  'cake': 856,
#  'emoji': 857,
#  'double': 858,
#  'yummy': 859,
#  'james': 860,
#  'mic': 861,
#  'cream': 862,
#  'debut': 863,
#  'obama': 864,
#  'ass': 865,
#  'hang': 866,
#  'lunch': 867,
#  'arent': 868,
#  'possible': 869,
#  'insane': 870,
#  'memory': 871,
#  'absolute': 872,
#  'bill': 873,
#  'mass': 874,
#  'booty': 875,
#  'shout': 876,
#  'attack': 877,
#  'weak': 878,
#  'rm': 879,
#  'tuesday': 880,
#  'tune': 881,
#  'jump': 882,
#  'mutiple': 883,
#  'subscribe': 884,
#  'spend': 885,
#  'fix': 886,
#  'plz': 887,
#  'smoke': 888,
#  'announce': 889,
#  'evil': 890,
#  'easter': 891,
#  'smell': 892,
#  'nut': 893,
#  'clinton': 894,
#  'channel': 895,
#  'bomb': 896,
#  'feature': 897,
#  'sooo': 898,
#  'til': 899,
#  'trip': 900,
#  'coach': 901,
#  'wild': 902,
#  'extra': 903,
#  'office': 904,
#  'shock': 905,
#  'officially': 906,
#  'weve': 907,
#  'handle': 908,
#  'stress': 909,
#  'crap': 910,
#  'ate': 911,
#  'bae': 912,
#  'totally': 913,
#  'vibe': 914,
#  'price': 915,
#  'fit': 916,
#  'force': 917,
#  'gun': 918,
#  'exol': 919,
#  'soo': 920,
#  'rise': 921,
#  'interview': 922,
#  'grab': 923,
#  'comeback': 924,
#  'everywhere': 925,
#  'service': 926,
#  'door': 927,
#  'total': 928,
#  'nah': 929,
#  'weather': 930,
#  'focus': 931,
#  'cheat': 932,
#  'session': 933,
#  'bos': 934,
#  'box': 935,
#  'action': 936,
#  'simple': 937,
#  'pure': 938,
#  'knife': 939,
#  'alert': 940,
#  'homie': 941,
#  'xxx': 942,
#  'stick': 943,
#  'success': 944,
#  'hotel': 945,
#  'grateful': 946,
#  'trans': 947,
#  'bar': 948,
#  'broken': 949,
#  'raise': 950,
#  'version': 951,
#  'prize': 952,
#  'road': 953,
#  'mutuals': 954,
#  'test': 955,
#  'war': 956,
#  'handsome': 957,
#  'slow': 958,
#  'meme': 959,
#  'relate': 960,
#  'kinda': 961,
#  'fill': 962,
#  'healthy': 963,
#  'low': 964,
#  'cook': 965,
#  'pas': 966,
#  'allah': 967,
#  'ad': 968,
#  'retweeting': 969,
#  'lay': 970,
#  'wet': 971,
#  'green': 972,
#  'makeup': 973,
#  'paint': 974,
#  'fandom': 975,
#  'heat': 976,
#  'cardi': 977,
#  'positive': 978,
#  'champion': 979,
#  'especially': 980,
#  'key': 981,
#  'cross': 982,
#  'hillary': 983,
#  'deserves': 984,
#  'idc': 985,
#  'experience': 986,
#  'boys': 987,
#  'warm': 988,
#  'fool': 989,
#  'jhope': 990,
#  'suppose': 991,
#  'legit': 992,
#  'fw': 993,
#  'style': 994,
#  'liberal': 995,
#  'patriot': 996,
#  'burn': 997,
#  'decide': 998,
#  'yr': 999,
#  'teacher': 1000,
#  ...}

# %%
vocabulary_size = len(tokenizer.word_index)
seq_len = 40
embed_len = 100 ### originally 20

model = Sequential()
model.add(Embedding(vocabulary_size+1, embed_len, input_length = seq_len))
model.add(LSTM(80, return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(40))
model.add(Dropout(0.5))
model.add(Dense(15, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 40, 100)           7263700
#
#  lstm (LSTM)                 (None, 40, 80)            57920
#
#  dropout (Dropout)           (None, 40, 80)            0
#
#  lstm_1 (LSTM)               (None, 40)                19360
#
#  dropout_1 (Dropout)         (None, 40)                0
#
#  dense (Dense)               (None, 15)                615
#
# =================================================================
# Total params: 7,341,595
# Trainable params: 7,341,595
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor="val_loss", mode="min", patience=1, verbose=1)

model.compile(
    loss = "categorical_crossentropy",
    optimizer = "adam",
    metrics = ["accuracy"]
)

# %%
tf.config.run_functions_eagerly(True)

batch_size = 128
epochs = 10

model.fit(
    X_train, 
    y_train, 
    batch_size = batch_size, 
    epochs = epochs, 
    shuffle = True,
    validation_data = (X_test, y_test),
    callbacks = [early_stop]
)
# Out:
# Epoch 1/10
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\data\ops\structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\data\ops\structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1225/1225 [==============================] - ETA: 0s - loss: 2.3178 - accuracy: 0.2596
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\data\ops\structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1225/1225 [==============================] - 674s 550ms/step - loss: 2.3178 - accuracy: 0.2596 - val_loss: 2.0621 - val_accuracy: 0.3520
# Epoch 2/10
# 1225/1225 [==============================] - 674s 551ms/step - loss: 1.9385 - accuracy: 0.4051 - val_loss: 1.9918 - val_accuracy: 0.3826
# Epoch 3/10
# 1225/1225 [==============================] - 678s 554ms/step - loss: 1.7115 - accuracy: 0.4858 - val_loss: 2.0104 - val_accuracy: 0.3899
# Epoch 3: early stopping

# %%
model.save("LSTM")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM\assets
# INFO:tensorflow:Assets written to: LSTM\assets

# %% [markdown]
# # Model Evaluation

# %%
y_test = df["emoji_id"].values
y_test = y_test[split_index:]

# %%
from sklearn.metrics import classification_report

predictions_prob = model.predict(X_test)
test_Y_pred = np.argmax(predictions_prob, axis = -1)
test_Y_pred
# Out:
#    1/2098 [..............................] - ETA: 4:01
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\data\ops\structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 2098/2098 [==============================] - 206s 98ms/step
# array([12, 12, 12, ...,  2, 12,  9], dtype=int64)

# %%
print(classification_report(y_test, test_Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.30      0.26      4462
#            1       0.29      0.26      0.28      4386
#            2       0.47      0.44      0.46      4466
#            3       0.27      0.34      0.30      4501
#            4       0.26      0.32      0.29      4513
#            5       0.34      0.23      0.27      4514
#            6       0.37      0.38      0.37      4504
#            7       0.45      0.37      0.41      4458
#            8       0.48      0.44      0.46      4370
#            9       0.52      0.49      0.50      4426
#           10       0.44      0.45      0.45      4468
#           11       0.57      0.60      0.58      4508
#           12       0.43      0.39      0.41      4532
#           13       0.37      0.36      0.37      4452
#           14       0.43      0.48      0.45      4571
#
#     accuracy                           0.39     67131
#    macro avg       0.40      0.39      0.39     67131
# weighted avg       0.40      0.39      0.39     67131

# %% [markdown]
# # Emoji Recommender Top k Evaluation

# %%
def top_k_prediction(prob, k):
    results = []
    for item in prob:
        # Create a copy of the original array to avoid modifying it
        arr_copy = item.copy()

        # Get the indices that would sort the array in ascending order
        sorted_indices = np.argsort(arr_copy)

        # Take the last 5 indices to get the indices of the top 5 elements
        top_indices = sorted_indices[-k:]
        
        results.append(top_indices)
        
    return results

# %%
result = test_df.copy()
top_3_predictions = top_k_prediction(predictions_prob, 3)
result["predicted_emoji_3"] = top_3_predictions
result["predicted_accurate_3"] = result.apply(lambda x: x.emoji_id in x.predicted_emoji_3, axis = 1)

# %%
# Top 3 accuracy - overall score
print(len(result[result["predicted_accurate_3"] == 1]) / len(result))
# Out:
# 0.6089883958230922

# %%
# Top 3 accuracy by Emoji
result["count"] = 1
result_top_3_aggregated = pd.DataFrame()
result_top_3_aggregated["emoji_id"] = result.groupby("emoji_id")['predicted_accurate_3'].sum().index.astype('str')
result_top_3_aggregated["count"] = result.groupby("emoji_id")['count'].sum().values
result_top_3_aggregated["accurate predictions"] = result.groupby("emoji_id")['predicted_accurate_3'].sum().values
result_top_3_aggregated = result_top_3_aggregated.sort_values('accurate predictions', ascending = False)
result_top_3_aggregated["accuracy"] = result_top_3_aggregated["accurate predictions"] / result_top_3_aggregated["count"]
result_top_3_aggregated["emoji_id"] = pd.to_numeric(result_top_3_aggregated["emoji_id"])
result_top_3_aggregated = result_top_3_aggregated.sort_values(by=['emoji_id'])
result_top_3_aggregated
# Out:
#     emoji_id  count  accurate predictions  accuracy
# 0          0   4462                  2682  0.601076
# 1          1   4386                  2555  0.582535
# 2          2   4466                  2694  0.603224
# 3          3   4501                  2863  0.636081
# 4          4   4513                  2904  0.643474
# 5          5   4514                  2540  0.562694
# 6          6   4504                  2593  0.575710
# 7          7   4458                  2579  0.578511
# 8          8   4370                  2459  0.562700
# 9          9   4426                  2799  0.632399
# 10        10   4468                  2898  0.648612
# 11        11   4508                  3148  0.698314
# 12        12   4532                  2654  0.585613
# 13        13   4452                  2523  0.566712
# 14        14   4571                  2991  0.654343

# %%
import matplotlib.pyplot as plt

x = result_top_3_aggregated["emoji_id"]
y = result_top_3_aggregated["accuracy"]

# Create the bar chart using the bar function
plt.bar(x, y)

# Add a title and axis labels
plt.title('Top 3 Accuracy by Emoji')
plt.xlabel('Emoji ID')
plt.ylabel('Accuracy')

# Display the plot
plt.show()
